# %%
import notebook_common
import jaconv
from importlib import reload

reload(notebook_common)
from notebook_common import (
    # ------------------function------------------
    # read_excel,
    to_csv_sig,
    # ------------------2400 word------------------
    # r_word_2400_xlsx,
    # w_word_2400_csv,
    # w_word_2400_with_guide_csv,
    w_word_2400_without_guide_csv,
    r_word_2400_v2_csv,
    # ------------------JLPT word------------------
    r_jlpt_csv,
    r_jlpt_v2_csv,
    w_jlpt_csv,
    w_jlpt_word_csv,
    w_jlpt_multiidx_agg_csv,
    r_jlpt_12000_csv,
    w_jlpt_12000_csv,
    # ------------------词性字典表------------------
    r_pos_dict_csv,
    # ------------------书面语相关------------------
    # 解析书面语正则
    # pattern_table_written,
    # pattern_td_written,
    # r_written_freq_nlt_with_enter_txt,
    # w_written_freq_nlt_with_enter_csv,
    # w_written_freq_nlt_sumed_csv,
    # ------------------口语相关------------------
    # 解析口头语正则
    # pattern_table_spoken,
    # pattern_td_spoken,
    # r_spoken_freq_nlb_with_enter_txt,
    # w_spoken_freq_nlb_with_enter_csv,
    # w_spoken_freq_nlb_with_enter_filtered_csv,
    # w_spoken_freq_nlb_with_enter_filtered_hrt_csv,
    # w_spoken_freq_nlb_sumed_csv,
    # ------------------合并书面语和口语词频------------------
    # w_merged_freq_sumed_csv,
    w_raw_merged_freq_sumed_csv,
    # ------------------公共python库------------------
    pd,
    np,
    p,
    re,
    l,
    fetch_random_from_set,
)

l("Import common module")
# Out:
# ----------------------------------------Import common module----------------------------------------

# %%
# 读取原始 jlpt文件
df_jlpt_12000 = pd.read_csv(
    r_jlpt_12000_csv,
    encoding="utf-8-sig",
    on_bad_lines="skip",
    engine="python",
    keep_default_na=False,
    # index_col=["word", "reading"]
)

# 读词性字典表
df_pos_dict = pd.read_csv(
    r_pos_dict_csv,
    encoding="utf-8-sig",
    on_bad_lines="skip",
    engine="python",
    # keep_default_na=False,
    # index_col=["word", "reading"]
)


df_jlpt_12000
# Out:
#                              level    word tone   ps  \
# 0                 NEW-JLPT::NEW-N5    〜やすい        接尾
# 1                 NEW-JLPT::NEW-N5     〜か月        接尾
# 2                 NEW-JLPT::NEW-N5   キログラム    ③    名
# 3                 NEW-JLPT::NEW-N5  キロメートル         名
# 4                 NEW-JLPT::NEW-N5     グラム   ①⓪    名
# ...                            ...     ...  ...  ...
# 12633  NEW-JLPT::NEW-N1::NEW-N1-核心     鎮める    ③  他動2
# 12634  NEW-JLPT::NEW-N3::NEW-N3-核心      付き         名
# 12635  NEW-JLPT::NEW-N1::NEW-N1-核心   罰[ばち]    ②    名
# 12636  NEW-JLPT::NEW-N2::NEW-N2-核心  潜[もぐ]る    ②  自動1
# 12637             NEW-JLPT::NEW-N5       十    ①    名
#
#                               hira             meaning
# 0                             〜やすい           简单的，容易……的
# 1                             〜かげつ                ……个月
# 2      (英) kilogram；(法) kilogramme               千克，公斤
# 3                    (法) kilomètre           ……千米，……公里
# 4              (英) gram；(法) gramme                   克
# ...                            ...                 ...
# 12633                         しずめる  镇定，平息（混乱）；镇，止住（疼痛）
# 12634                           つき            附着；燃烧；运气
# 12635                           ばち                  报应
# 12636                          もぐる            潜水；躲入，钻进
# 12637                           とお             十；十个；十岁
#
# [12638 rows x 6 columns]

# %%
df_pos_dict
# Out:
#     pos_id  parent_id   pos  verb_zita  verb_is_sup  verb_is_aux  is_optional
# 0       10          0    名词        NaN          NaN          NaN            1
# 1       11          0    代词        NaN          NaN          NaN            1
# 2       12          0   接头词        NaN          NaN          NaN            1
# 3       13          0   接尾词        NaN          NaN          NaN            1
# 4       14          0   感叹词        NaN          NaN          NaN            1
# 5       15          0   形容词        NaN          NaN          NaN            0
# 6       16         15    形1        NaN          NaN          NaN            1
# 7       17         15    形2        NaN          NaN          NaN            1
# 8       18          0    副词        NaN          NaN          NaN            1
# 9       19          0    动词        NaN          NaN          NaN            0
# 10      20         19    动1        NaN          NaN          NaN            1
# 11      21         19    动2        NaN          NaN          NaN            1
# 12      22         19    动3        NaN          NaN          NaN            1
# 13      25          0    连词        NaN          NaN          NaN            1
# 14      26          0    助词        NaN          NaN          NaN            1
# 15      27         26   格助词        NaN          NaN          NaN            1
# 16      28         26   终助词        NaN          NaN          NaN            1
# 17      29         26  接续助词        NaN          NaN          NaN            1
# 18      30         26   系助词        NaN          NaN          NaN            1
# 19      31         26   副助词        NaN          NaN          NaN            1
# 20      32         26  并立助词        NaN          NaN          NaN            1
# 21      33          0   连体词        NaN          NaN          NaN            1
# 22      34          0   拟声词        NaN          NaN          NaN            1
# 23      35          0   拟态词        NaN          NaN          NaN            1
# 24      36          0   惯用句        NaN          NaN          NaN            1

# %%
# 去除多余的~
def clean_title(val):
    if pd.isna(val) or val == "":
        return val
    return re.sub(r"^~|^〜|^～|^—|~$|～$|〜$", "", str(val))


df_jlpt_12000["cnt_word"] = df_jlpt_12000.groupby(["word"]).transform("size")



# 将其~开头或结尾的值删除
df_jlpt_12000["word"] = df_jlpt_12000["word"].astype(str).apply(clean_title)
df_jlpt_12000["hira"] = df_jlpt_12000["hira"].astype(str).apply(clean_title)
df_jlpt_12000
# Out:
#                              level    word tone   ps  \
# 0                 NEW-JLPT::NEW-N5     やすい        接尾
# 1                 NEW-JLPT::NEW-N5      か月        接尾
# 2                 NEW-JLPT::NEW-N5   キログラム    ③    名
# 3                 NEW-JLPT::NEW-N5  キロメートル         名
# 4                 NEW-JLPT::NEW-N5     グラム   ①⓪    名
# ...                            ...     ...  ...  ...
# 12633  NEW-JLPT::NEW-N1::NEW-N1-核心     鎮める    ③  他動2
# 12634  NEW-JLPT::NEW-N3::NEW-N3-核心      付き         名
# 12635  NEW-JLPT::NEW-N1::NEW-N1-核心   罰[ばち]    ②    名
# 12636  NEW-JLPT::NEW-N2::NEW-N2-核心  潜[もぐ]る    ②  自動1
# 12637             NEW-JLPT::NEW-N5       十    ①    名
#
#                               hira             meaning  cnt_word
# 0                              やすい           简单的，容易……的         1
# 1                              かげつ                ……个月         1
# 2      (英) kilogram；(法) kilogramme               千克，公斤         1
# 3                    (法) kilomètre           ……千米，……公里         1
# 4              (英) gram；(法) gramme                   克         1
# ...                            ...                 ...       ...
# 12633                         しずめる  镇定，平息（混乱）；镇，止住（疼痛）         1
# 12634                           つき            附着；燃烧；运气         1
# 12635                           ばち                  报应         1
# 12636                          もぐる            潜水；躲入，钻进         1
# 12637                           とお             十；十个；十岁         2
#
# [12638 rows x 7 columns]

# %%
# 拆分 ・
split_df = df_jlpt_12000["ps"].str.split("・", n=3, expand=True)
df_jlpt_12000["prop1"] = split_df[0].fillna("")
df_jlpt_12000["prop2"] = split_df[1].fillna("")
df_jlpt_12000["prop3"] = split_df[2].fillna("")
df_jlpt_12000["prop4"] = split_df[3].fillna("")
to_csv_sig(df_jlpt_12000,w_jlpt_12000_csv)
l('df_jlpt_12000')
df_jlpt_12000
# Out:
# ----------------------------------------df_jlpt_12000----------------------------------------
#                              level    word tone   ps  \
# 0                 NEW-JLPT::NEW-N5     やすい        接尾
# 1                 NEW-JLPT::NEW-N5      か月        接尾
# 2                 NEW-JLPT::NEW-N5   キログラム    ③    名
# 3                 NEW-JLPT::NEW-N5  キロメートル         名
# 4                 NEW-JLPT::NEW-N5     グラム   ①⓪    名
# ...                            ...     ...  ...  ...
# 12633  NEW-JLPT::NEW-N1::NEW-N1-核心     鎮める    ③  他動2
# 12634  NEW-JLPT::NEW-N3::NEW-N3-核心      付き         名
# 12635  NEW-JLPT::NEW-N1::NEW-N1-核心   罰[ばち]    ②    名
# 12636  NEW-JLPT::NEW-N2::NEW-N2-核心  潜[もぐ]る    ②  自動1
# 12637             NEW-JLPT::NEW-N5       十    ①    名
#
#                               hira             meaning  cnt_word prop1 prop2  \
# 0                              やすい           简单的，容易……的         1    接尾
# 1                              かげつ                ……个月         1    接尾
# 2      (英) kilogram；(法) kilogramme               千克，公斤         1     名
# 3                    (法) kilomètre           ……千米，……公里         1     名
# 4              (英) gram；(法) gramme                   克         1     名
# ...                            ...                 ...       ...   ...   ...
# 12633                         しずめる  镇定，平息（混乱）；镇，止住（疼痛）         1   他動2
# 12634                           つき            附着；燃烧；运气         1     名
# 12635                           ばち                  报应         1     名
# 12636                          もぐる            潜水；躲入，钻进         1   自動1
# 12637                           とお             十；十个；十岁         2     名
#
#       prop3 prop4
# 0
# 1
# 2
# 3
# 4
# ...     ...   ...
# 12633
# 12634
# 12635
# 12636
# 12637
#
# [12638 rows x 11 columns]

# %%
# 处理自 他
# 处理A/B/C/D列并生成对应X1列
for col in ["prop1", "prop2", "prop3", "prop4"]:
    # 提取前缀和动后部分
    extracted = df_jlpt_12000[col].str.extract(r"^(他|自|自他)(動[1-3].*)$")

    # 更新原列内容
    df_jlpt_12000[col] = np.where(
        extracted[1].notna(),
        extracted[1],
        df_jlpt_12000[col],  # 匹配成功时取动后部分  # 匹配失败时保留原值
    )

    # 新增X1列
    df_jlpt_12000[f"{col}_z"] = extracted[0].fillna("")
# 生成X列：取第一个非空的X1列
df_jlpt_12000["type"] = df_jlpt_12000[["prop1_z", "prop2_z", "prop3_z", "prop4_z"]].apply(
    lambda row: next((val for val in row if val != ""), ""), axis=1
)
to_csv_sig(df_jlpt_12000, w_jlpt_12000_csv)
l("df_jlpt_12000")
df_jlpt_12000
# Out:
# ----------------------------------------df_jlpt_12000----------------------------------------
#                              level    word tone   ps  \
# 0                 NEW-JLPT::NEW-N5     やすい        接尾
# 1                 NEW-JLPT::NEW-N5      か月        接尾
# 2                 NEW-JLPT::NEW-N5   キログラム    ③    名
# 3                 NEW-JLPT::NEW-N5  キロメートル         名
# 4                 NEW-JLPT::NEW-N5     グラム   ①⓪    名
# ...                            ...     ...  ...  ...
# 12633  NEW-JLPT::NEW-N1::NEW-N1-核心     鎮める    ③  他動2
# 12634  NEW-JLPT::NEW-N3::NEW-N3-核心      付き         名
# 12635  NEW-JLPT::NEW-N1::NEW-N1-核心   罰[ばち]    ②    名
# 12636  NEW-JLPT::NEW-N2::NEW-N2-核心  潜[もぐ]る    ②  自動1
# 12637             NEW-JLPT::NEW-N5       十    ①    名
#
#                               hira             meaning  cnt_word prop1 prop2  \
# 0                              やすい           简单的，容易……的         1    接尾
# 1                              かげつ                ……个月         1    接尾
# 2      (英) kilogram；(法) kilogramme               千克，公斤         1     名
# 3                    (法) kilomètre           ……千米，……公里         1     名
# 4              (英) gram；(法) gramme                   克         1     名
# ...                            ...                 ...       ...   ...   ...
# 12633                         しずめる  镇定，平息（混乱）；镇，止住（疼痛）         1    動2
# 12634                           つき            附着；燃烧；运气         1     名
# 12635                           ばち                  报应         1     名
# 12636                          もぐる            潜水；躲入，钻进         1    動1
# 12637                           とお             十；十个；十岁         2     名
#
#       prop3 prop4 prop1_z prop2_z prop3_z prop4_z type
# 0
# 1
# 2
# 3
# 4
# ...     ...   ...     ...     ...     ...     ...  ...
# 12633                   他                            他
# 12634
# 12635
# 12636                   自                            自
# 12637
#
# [12638 rows x 16 columns]

# %%
# 字符串替换
replace_dict = {
    "動1": "动1",
    "接頭": "接头词",
    "接尾": "接尾词",
    "連体": "连体词",
    "名名": "名词",
    "接": "连词",
    "イ形": "形1",
    "ナ形": "形2",
    "動2": "动2",
    "動3": "动3",
    "代": "代词",
    "名": "名词",
    "感": "感叹词",
    "副": "副词",
}
cols = ["prop1", "prop2", "prop3", "prop4"]
df_jlpt_12000[cols] = df_jlpt_12000[cols].replace(replace_dict)
#
df_jlpt_12000["remark"] = ""  # 先初始化为空
df_jlpt_12000.loc[df_jlpt_12000["hira"].str.startswith("("), "remark"] = df_jlpt_12000[
    "hira"
]

df_jlpt_12000["hira"] = np.where(
    df_jlpt_12000["hira"].str.startswith("("),
    df_jlpt_12000["word"].apply(jaconv.kata2hira),
    df_jlpt_12000["hira"],
)

to_csv_sig(df_jlpt_12000, w_jlpt_12000_csv)
l("df_jlpt_12000")
df_jlpt_12000
# Out:
# ----------------------------------------df_jlpt_12000----------------------------------------
#                              level    word tone   ps    hira  \
# 0                 NEW-JLPT::NEW-N5     やすい        接尾     やすい
# 1                 NEW-JLPT::NEW-N5      か月        接尾     かげつ
# 2                 NEW-JLPT::NEW-N5   キログラム    ③    名   きろぐらむ
# 3                 NEW-JLPT::NEW-N5  キロメートル         名  きろめーとる
# 4                 NEW-JLPT::NEW-N5     グラム   ①⓪    名     ぐらむ
# ...                            ...     ...  ...  ...     ...
# 12633  NEW-JLPT::NEW-N1::NEW-N1-核心     鎮める    ③  他動2    しずめる
# 12634  NEW-JLPT::NEW-N3::NEW-N3-核心      付き         名      つき
# 12635  NEW-JLPT::NEW-N1::NEW-N1-核心   罰[ばち]    ②    名      ばち
# 12636  NEW-JLPT::NEW-N2::NEW-N2-核心  潜[もぐ]る    ②  自動1     もぐる
# 12637             NEW-JLPT::NEW-N5       十    ①    名      とお
#
#                   meaning  cnt_word prop1 prop2 prop3 prop4 prop1_z prop2_z  \
# 0               简单的，容易……的         1   接尾词
# 1                    ……个月         1   接尾词
# 2                   千克，公斤         1    名词
# 3               ……千米，……公里         1    名词
# 4                       克         1    名词
# ...                   ...       ...   ...   ...   ...   ...     ...     ...
# 12633  镇定，平息（混乱）；镇，止住（疼痛）         1    动2                         他
# 12634            附着；燃烧；运气         1    名词
# 12635                  报应         1    名词
# 12636            潜水；躲入，钻进         1    动1                         自
# 12637             十；十个；十岁         2    名词
#
#       prop3_z prop4_z type                       remark
# 0
# 1
# 2                           (英) kilogram；(法) kilogramme
# 3                                         (法) kilomètre
# 4                                   (英) gram；(法) gramme
# ...       ...     ...  ...                          ...
# 12633                    他
# 12634
# 12635
# 12636                    自
# 12637
#
# [12638 rows x 17 columns]

# %%
# 查询 2400词汇在 12000里的比例
# 读取原始2400词汇 V2 csv
df_2400_v2 = pd.read_csv(
    w_word_2400_without_guide_csv,
    encoding="utf-8-sig",
    on_bad_lines="skip",
    engine="python",
    keep_default_na=False,
)
df_2400_v2
# Out:
#       number     word     hira    pos prop1 sub_prop1 prop2 sub_prop2 prop3  \
# 0          1       ああ       ああ          感叹词
# 1          2        愛       あい    五十音    名词              动词        动3
# 2          3     あいさつ     あいさつ           名词              动词        动3
# 3          4       合図      あいず           名词
# 4          5  アイスクリーム  あいすくりーむ           名词
# ...      ...      ...      ...    ...   ...       ...   ...       ...   ...
# 2459    2460        象       ぞう  Ｌ13-2    名词
# 2460    2461       東京    とうきょう  Ｌ13-2    名词
# 2461    2462       居間       いま    Ｌ14    名词
# 2462    2463      中学生  ちゅうがくせい    Ｌ14    名词
# 2463    2464      小学校  しょうがっこう    Ｌ14    名词
#
#      sub_prop3 remark   meaning  cnt-word  cnt-word-hira
# 0                      啊、嗯、啊呀、唉         1              1
# 1                   他     爱情、爱好         1              1
# 2                   自     寒暄、致辞         1              1
# 3                            信号         1              1
# 4                        冰激凌、雪糕         1              1
# ...        ...    ...       ...       ...            ...
# 2459                         大象         1              1
# 2460                         东京         1              1
# 2461                    起居室，起坐间         1              1
# 2462                        中学生         1              1
# 2463                         小学         1              1
#
# [2464 rows x 14 columns]

# %%
# 1. 2400的词汇有多少在12000里
word_2400_v2_set = set(df_2400_v2["word"])
p(f"word size in 2400_v2:{len(word_2400_v2_set)}")
word_12000_set = set(df_jlpt_12000["word"])
p(f"word size in 12000:{len(word_12000_set)}")

word_intersection = word_2400_v2_set & word_12000_set
len_word_2400_v2_set = len(word_2400_v2_set)
len_word_found = len(word_intersection)
per_word_found = len_word_found / len_word_2400_v2_set
len_word_unfound = len_word_2400_v2_set - len_word_found
per_word_unfound = len_word_unfound / len_word_2400_v2_set
p(f"word size in 2400_v2:{len_word_2400_v2_set}")
p(f"word_intersection:{len_word_found}({per_word_found:.1%})")
p(f"unfound word in 2400_v2:{len_word_unfound}({per_word_unfound:.1%})")
# Out:
# word size in 2400_v2:2435
# word size in 12000:12585
# word size in 2400_v2:2435
# word_intersection:2182(89.6%)
# unfound word in 2400_v2:253(10.4%)

# %%
# 输出一个12000的子集，用于给2400词汇作参考
df_12000_word_idx = df_jlpt_12000.set_index("word")
df_2400_word_idx = df_2400_v2.set_index("word")
df_12000_simple = df_12000_word_idx[
    df_12000_word_idx.index.isin(df_2400_word_idx.index)
]
to_csv_sig(df_12000_simple, "d:/tmp/df_12000_simple.csv", True)
df_12000_simple
# Out:
#                             level tone     ps  hira              meaning  \
# word
# やすい              NEW-JLPT::NEW-N5          接尾   やすい            简单的，容易……的
# さん               NEW-JLPT::NEW-N5          接尾    さん  （表达敬意或亲近感）……先生，……女士
# すぎ               NEW-JLPT::NEW-N5          接尾    すぎ            过分……，过度……
# ちゃん              NEW-JLPT::NEW-N4          接尾   ちゃん         （“さん”的昵称）小……
# にくい              NEW-JLPT::NEW-N5       接尾・イ形   にくい                  难……
# ...                           ...  ...    ...   ...                  ...
# 美術               NEW-JLPT::NEW-N4    ①      名  びじゅつ                   美术
# 門                NEW-JLPT::NEW-N5    ①      名    もん                   大门
# 年                NEW-JLPT::NEW-N5        接尾・名    ねん                  ……年
# 速い               NEW-JLPT::NEW-N5    ②     イ形   はやい               快的，迅速的
# 遭う    NEW-JLPT::NEW-N3::NEW-N3-核心    ①    自動1    あう            遇到（不好的事情）
#
#       cnt_word prop1 prop2 prop3 prop4 prop1_z prop2_z prop3_z prop4_z type  \
# word
# やすい          1   接尾词
# さん           1   接尾词
# すぎ           1   接尾词
# ちゃん          1   接尾词
# にくい          1   接尾词    形1
# ...        ...   ...   ...   ...   ...     ...     ...     ...     ...  ...
# 美術           1    名词
# 門            1    名词
# 年            1   接尾词    名词
# 速い           1    形1
# 遭う           1    动1                         自                            自
#
#      remark
# word
# やすい
# さん
# すぎ
# ちゃん
# にくい
# ...     ...
# 美術
# 門
# 年
# 速い
# 遭う
#
# [2216 rows x 16 columns]
