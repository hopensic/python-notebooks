# %%
import sys
import os
import pickle

# 获取当前 Notebook 所在目录的上层目录
upper_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
# 将上层目录添加到 sys.path
sys.path.append(upper_dir)

# 导入上层目录中的 Python 文件（假设文件名为 module.py）
import notebook_common


import jaconv
import cutlet


from importlib import reload

reload(notebook_common)
from notebook_common import (
    # ------------------function------------------
    # read_excel,
    to_csv_sig,
    # ------------------2400 word------------------
    # r_word_2400_xlsx,
    # w_word_2400_csv,
    # w_word_2400_with_guide_csv,
    w_word_2400_without_guide_csv,
    # ------------------书面语相关------------------
    # 解析书面语正则
    # pattern_table_written,
    # pattern_td_written,
    # r_written_freq_nlt_with_enter_txt,
    # w_written_freq_nlt_with_enter_csv,
    w_written_freq_nlt_sumed_csv,
    # ------------------口语相关------------------
    # 解析口头语正则
    # pattern_table_spoken,
    # pattern_td_spoken,
    # r_spoken_freq_nlb_with_enter_txt,
    # w_spoken_freq_nlb_with_enter_csv,
    # w_spoken_freq_nlb_with_enter_filtered_csv,
    # w_spoken_freq_nlb_with_enter_filtered_hrt_csv,
    w_spoken_freq_nlb_sumed_csv,
    # ------------------合并书面语和口语词频------------------
    w_merged_freq_sumed_csv,
    w_raw_merged_freq_sumed_csv,
    w_word_raw_merged_freq_sumed_csv,
    #---------------------------词义相关---------------------------------
    simple_meaning_increase_30000_csv,


    # ------------------公共python库------------------
    pd,
    np,
    p,
    l,
)

p("Import common module")
# Out:
# Import common module

# %%
# 读取最新的 基础词频表 (带精简词义，kanji_type,罗马音，spell_type)
df_merged_raw_word_agg = pd.read_csv(
    'D:/Dropbox/06.wanjuan/99.tmp/df_base_freq_new22_to_del.csv',
    encoding="utf-8-sig",
    on_bad_lines="skip",
    engine="python",
    # keep_default_na=False,
    # index_col=["headword"]
)


# 读取合并后的词频表
df_merged_freq = pd.read_csv(
    'D:/Dropbox/06.wanjuan/99.tmp/df_all_m4_0.7_0.2_0.1.csv',
    encoding="utf-8-sig",
    on_bad_lines="skip",
    engine="python",
    # keep_default_na=False,
    # index_col=["headword"]
)


df_merged_raw_word_agg
# Out:
#         word_id spell  frequency  spoken_freq  written_freq    mix_freq  \
# 0        100000     の          1   57221425.0      686025.0  43219589.0
# 1        100001     に          2   35286930.0           0.0  23536382.0
# 2        100002     を          3   33707106.0           0.0  22482640.0
# 3        100003     は          4   31279365.0           0.0  20863336.0
# 4        100004     が          5   30705135.0           0.0  20480325.0
# ...         ...   ...        ...          ...           ...         ...
# 102508   202508   友だち     102509          0.0           0.0         0.0
# 102509   202509    範圍     102510          0.0           0.0         0.0
# 102510   202510    勿論     102511          0.0           0.0         0.0
# 102511   202511     紐     102512          0.0           0.0         0.0
# 102512   202512    北京     102513          0.0           0.0         0.0
#
#         pron_count  spell_type simple_meaning meaning_origin      roman  \
# 0                1           0         的；所属               dp         No
# 1                1           0          在；向               dp         Ni
# 2                1           0         宾语助词               dp         Wo
# 3                1           0         主题助词               dp         Wa
# 4                1           0         主语助词               dp         Ga
# ...            ...         ...            ...            ...        ...
# 102508           1           1             朋友           grok  Tomodachi
# 102509           1           1            NaN             dp      Han'i
# 102510           1           1             当然           grok   Mochiron
# 102511           1           1             绳子           grok       Himo
# 102512           1           1             北京           grok      Pekin
#
#         has_kanji  hiragana_range  katakana_range  code  kanji_type
# 0           False            True           False     2           5
# 1           False            True           False     2           5
# 2           False            True           False     2           5
# 3           False            True           False     2           5
# 4           False            True           False     2           5
# ...           ...             ...             ...   ...         ...
# 102508       True            True           False     6           2
# 102509       True           False           False     4           1
# 102510       True           False           False     4           1
# 102511       True           False           False     4           1
# 102512       True           False           False     4           1
#
# [102513 rows x 16 columns]

# %%
df_merged_freq
# Out:
#         Unnamed: 0  final_freq spell_all  long_word_rank bccwj_lemma  \
# 0                0        1.00         の             1.0           の
# 1                1        2.00         は             2.0           は
# 2                2        3.00         に             4.0           に
# 3                3        4.00         が             6.0           が
# 4                4        5.00         を             3.0           を
# ...            ...         ...       ...             ...         ...
# 133632      133632    18486.33      ＴＶする             NaN         NaN
# 133633      133633    18486.34     ＴＫＯする             NaN         NaN
# 133634      133634    18486.35      エロする             NaN         NaN
# 133635      133635    18486.36      ｋｇする             NaN         NaN
# 133636      133636    18486.37      ｋワット             NaN         NaN
#
#         bccwj_freq_per ck_long_word  base_word_rank   word_id base_word  ...  \
# 0             0.067922         both             1.0  100000.0         の  ...
# 1             0.038481         both             4.0  100003.0         は  ...
# 2             0.036494         both             2.0  100001.0         に  ...
# 3             0.033505         both             5.0  100004.0         が  ...
# 4             0.037761         both             3.0  100002.0         を  ...
# ...                ...          ...             ...       ...       ...  ...
# 133632        0.000000    left_only         93911.0  202280.0      ＴＶする  ...
# 133633        0.000000    left_only         93925.0  193869.0     ＴＫＯする  ...
# 133634        0.000000    left_only         95182.0  195108.0      エロする  ...
# 133635        0.000000    left_only         93932.0  202281.0      ｋｇする  ...
# 133636        0.000000    left_only        102296.0  202302.0      ｋワット  ...
#
#         base_freq_per  ck_base_word 5000_word_rank  5000_spell 5000_freq  \
# 0        4.550477e-02          both            1.0           の   82484.0
# 1        2.196646e-02          both            2.0           は   61646.0
# 2        2.478084e-02          both            4.0           に   55237.0
# 3        2.156320e-02          both            5.0           が   54221.0
# 4        2.367138e-02          both            6.0           を   51021.0
# ...               ...           ...            ...         ...       ...
# 133632   1.100000e-09          both            NaN         NaN       NaN
# 133633   1.100000e-09          both            NaN         NaN       NaN
# 133634   1.100000e-09          both            NaN         NaN       NaN
# 133635   1.100000e-09          both            NaN         NaN       NaN
# 133636   1.100000e-09          both            NaN         NaN       NaN
#
#         5000_freq_per  ck_5000_word 2400_spell ck_2400_word final_freq_per
# 0            0.053508          both        NaN    left_only   5.559069e-02
# 1            0.039990          both        NaN    left_only   3.788603e-02
# 2            0.035833          both        NaN    left_only   3.485991e-02
# 3            0.035174          both        NaN    left_only   3.347886e-02
# 4            0.033098          both        NaN    left_only   3.308786e-02
# ...               ...           ...        ...          ...            ...
# 133632       0.000000     left_only        NaN    left_only   1.100000e-10
# 133633       0.000000     left_only        NaN    left_only   1.100000e-10
# 133634       0.000000     left_only        NaN    left_only   1.100000e-10
# 133635       0.000000     left_only        NaN    left_only   1.100000e-10
# 133636       0.000000     left_only        NaN    left_only   1.100000e-10
#
# [133637 rows x 21 columns]

# %%
# 筛选出不在原词汇表中的词频
# df_merged_freq_not_in_base = df_merged_freq[
#     ~df_merged_freq["spell_all"].isin(df_merged_raw_word_agg["spell"])
# ]
# df_merged_freq_not_in_base


# 把2400词汇spell填充到df_merged_freq的 spell_all字段里
df_merged_freq["spell_all"] = df_merged_freq["spell_all"].fillna(
    df_merged_freq["2400_spell"]
)


# 合并(新词频表和原10万基础词条表)
df_merged_all_freq = pd.merge(
    df_merged_raw_word_agg,
    df_merged_freq[
        [
            "spell_all",
            "2400_spell",
            "final_freq",
            "ck_long_word",
            "ck_base_word",
            "ck_5000_word",
            "ck_2400_word",
        ]
    ],
    left_on="spell",
    right_on="spell_all",
    how="outer",
    indicator="ck_all_word",
)

to_csv_sig(df_merged_all_freq, "D:/Dropbox/06.wanjuan/99.tmp/df_merged_all_freq.csv")
l("ok")
# Out:
# ----------------------------------------ok----------------------------------------

# %%
# 不需要增加word_id的基础词条数据
to_retain_data = df_merged_all_freq[
    df_merged_all_freq["ck_all_word"] == "both"
].copy()
l('ok')
to_retain_data
# Out:
# ----------------------------------------ok----------------------------------------
#          word_id   spell  frequency  spoken_freq  written_freq  mix_freq  \
# 0       133627.0    110番    33628.0          0.0         108.0     795.0
# 1       168219.0  110番する    68220.0          0.0           7.0      52.0
# 2       103328.0      1つ     3329.0          0.0        4366.0   32158.0
# 3       180122.0    1つする    80123.0          0.0           2.0      15.0
# 4       134814.0     2ラン    34815.0          0.0          99.0     729.0
# ...          ...     ...        ...          ...           ...       ...
# 133632  193837.0   ｓｕｐｅｒ    93838.0          3.0           0.0       2.0
# 133633  128590.0       ｔ    28591.0       1760.0           0.0    1174.0
# 133634  170832.0     ｔｈｅ    70833.0         60.0           0.0      40.0
# 133635  163306.0       ｖ    63307.0        119.0           0.0      79.0
# 133636  182058.0       ｗ    82059.0         20.0           0.0      13.0
#
#         pron_count  spell_type simple_meaning meaning_origin  ... code  \
# 0              1.0         0.0           报警电话             dp  ...  4.0
# 1              1.0         0.0             报警             dp  ...  6.0
# 2              1.0         0.0             一个             dp  ...  2.0
# 3              1.0         0.0          分成一部分             dp  ...  2.0
# 4              1.0         0.0            二垒打             dp  ...  1.0
# ...            ...         ...            ...            ...  ...  ...
# 133632         1.0         0.0           超级               dp  ...  0.0
# 133633         1.0         0.0              吨             dp  ...  0.0
# 133634         1.0         0.0         定冠词；那个             dp  ...  0.0
# 133635         1.0         0.0             胜利             dp  ...  0.0
# 133636         1.0         0.0        笑（网络用语）             dp  ...  0.0
#
#        kanji_type spell_all 2400_spell  final_freq  ck_long_word ck_base_word  \
# 0             1.0      110番        NaN    15634.31     left_only         both
# 1             2.0    110番する        NaN    17602.25     left_only         both
# 2             5.0        1つ        NaN     9823.00     left_only         both
# 3             5.0      1つする        NaN    18276.36     left_only         both
# 4             6.0       2ラン        NaN    15684.75     left_only         both
# ...           ...       ...        ...         ...           ...          ...
# 133632        8.0     ｓｕｐｅｒ        NaN    18386.01     left_only         both
# 133633        8.0         ｔ        NaN    15465.06     left_only         both
# 133634        8.0       ｔｈｅ        NaN    17788.00     left_only         both
# 133635        8.0         ｖ        NaN    17317.31     left_only         both
# 133636        8.0         ｗ        NaN    18284.95     left_only         both
#
#        ck_5000_word  ck_2400_word ck_all_word
# 0         left_only     left_only        both
# 1         left_only     left_only        both
# 2         left_only     left_only        both
# 3         left_only     left_only        both
# 4         left_only     left_only        both
# ...             ...           ...         ...
# 133632    left_only     left_only        both
# 133633    left_only     left_only        both
# 133634    left_only     left_only        both
# 133635    left_only     left_only        both
# 133636    left_only     left_only        both
#
# [102513 rows x 24 columns]

# %%
# 开始构建需要增加word_id的词条
to_insert_data = df_merged_all_freq[
    df_merged_all_freq["ck_all_word"] == "right_only"
].copy()
to_insert_data['word_id']=range(210000, 210000 + len(to_insert_data))
to_insert_data[["pron_count", "spell_type", "meaning_origin"]] = 1, 0, "dp"
to_insert_data["roman"] = to_insert_data["spell_all"].apply(jaconv.kata2hira)
katsu = cutlet.Cutlet()
to_insert_data["roman"] = to_insert_data["spell_all"].apply(katsu.romaji)
l("ok")
to_csv_sig(to_insert_data, "D:/Dropbox/06.wanjuan/99.tmp/to_insert_data.csv")
# Out:
# ----------------------------------------ok----------------------------------------

# %%
kanji_range = r"[\u4E00-\u9FCF]"
hiragana_range = r"[\u3040-\u309F]"
katakana_range = r"[\u30A0-\u30FF]"

# 检测字符类型
# has_kanji = bool(re.search(kanji_range, text))
# has_hiragana = bool(re.search(hiragana_range, text))
# has_katakana = bool(re.search(katakana_range, text))

to_insert_data["has_kanji"] = to_insert_data["spell_all"].str.contains(kanji_range)
to_insert_data["hiragana_range"] = to_insert_data["spell_all"].str.contains(hiragana_range)
to_insert_data["katakana_range"] = to_insert_data["spell_all"].str.contains(katakana_range)

to_insert_data["code"] = (
    (to_insert_data["has_kanji"].astype(int) * 4)
    | (to_insert_data["hiragana_range"].astype(int) * 2)
    | (to_insert_data["katakana_range"].astype(int))
)


value_map = {
    4: 1,  # 1. 汉字：只包含汉字，例如「日本語」。(100)
    6: 2,  # 2. 汉字和平假名：包含汉字和平假名，例如「漢字ひらがな」。(110)
    5: 3,  # 3. 汉字和片假名：包含汉字和片假名，例如「漢字カタカナ」。(101)
    7: 4,  # 4. 汉字、平假名和片假名：包含汉字、平假名和片假名，例如「漢字ひらカタ」。(111)
    2: 5,  # 5. 纯平假名：只包含平假名，例如「ひらがな」。(010)
    1: 6,  # 6. 纯片假名：只包含片假名，例如「カタカナ」。(001)
    3: 7,  # 7. 平假名和片假名混合：包含平假名和片假名，例如「ひらカタ」。(011)
    0: 8,  # 8. 其它 (000)
}

to_insert_data["kanji_type"] = to_insert_data["code"].map(value_map)
l("ok")
to_csv_sig(to_insert_data, "D:/Dropbox/06.wanjuan/99.tmp/to_insert_data.csv")
# Out:
# ----------------------------------------ok----------------------------------------

# %% [raw]
# # 读已调过Deepseek的生成的30000条精简词义
#
# df_simple_meaning_30000 = pd.read_csv(
#     "D:/Dropbox/06.wanjuan/99.tmp/30000-simple-meaning.csv",
#     encoding="utf-8-sig",
#     on_bad_lines="skip",
#     engine="python",
# )
#
# df_30000_merged_simple_meaning = pd.merge(
#     to_insert_data,
#     df_simple_meaning_30000,
#     left_on="spell_all",
#     right_on="spell",
#     how="left",
#     indicator="ck_merged",
# )
#
# to_csv_sig(
#     df_30000_merged_simple_meaning,
#     "D:/Dropbox/06.wanjuan/99.tmp/df_30000_merged_simple_meaning.csv",
# )
# l("ok")

# %%
df_30000_merged_simple_meaning = pd.read_csv(
    simple_meaning_increase_30000_csv,
    encoding="utf-8-sig",
    on_bad_lines="skip",
    engine="python",
)

df_30000_merged_simple_meaning.rename(columns={"spell_x": "spell"}, inplace=True)
df_30000_merged_simple_meaning["spell"] = df_30000_merged_simple_meaning["spell_all"]
df_30000_merged_simple_meaning["simple_meaning"] = df_30000_merged_simple_meaning[
    "meaning"
]
df_30000_merged_simple_meaning = df_30000_merged_simple_meaning.drop(
    ["spell_y", "meaning", "ck_merged"], axis=1
)
to_csv_sig(
    df_30000_merged_simple_meaning,
    "D:/Dropbox/06.wanjuan/99.tmp/df_30000_merged_simple_meaning.csv",
)
l("ok")
# Out:
# ----------------------------------------ok----------------------------------------

# %%
# 最终合并的数据集
df_increased_3000_final = pd.concat(
    [to_retain_data, df_30000_merged_simple_meaning], ignore_index=True
)
df_increased_3000_final["frequency"] = df_increased_3000_final["final_freq"]

del df_increased_3000_final["spell_all"]
del df_increased_3000_final["2400_spell"]
del df_increased_3000_final["final_freq"]
del df_increased_3000_final["ck_2400_word"]


df_increased_3000_final = df_increased_3000_final.sort_values(["frequency"])
to_csv_sig(
    df_increased_3000_final,
    "D:/Dropbox/06.wanjuan/99.tmp/df_increased_3000_final.csv",
)
l("ok")
# Out:
# ----------------------------------------ok----------------------------------------

# %%
df_increased_3000_final["spell_noise"] = df_increased_3000_final["spell"].apply(
    lambda x: "|".join(list(x))
)
to_csv_sig(
    df_increased_3000_final,
    "D:/Dropbox/06.wanjuan/99.tmp/df_increased_3000_final_v2.csv",
)
l("ok")
# Out:
# ----------------------------------------ok----------------------------------------

# %%
df_len_1_hira = df_increased_3000_final[
    (df_increased_3000_final["spell"].str.len() == 1)
    & (df_increased_3000_final["code"] == 2)
].copy()
df_len_1_hira
# Out:
#          word_id spell  frequency  spoken_freq  written_freq    mix_freq  \
# 6582    100000.0     の       1.00   57221425.0      686025.0  43219589.0
# 6712    100003.0     は       2.00   31279365.0           0.0  20863336.0
# 6246    100001.0     に       3.00   35286930.0           0.0  23536382.0
# 2343    100004.0     が       4.00   30705135.0           0.0  20480325.0
# 9257    100002.0     を       5.00   33707106.0           0.0  22482640.0
# ...          ...   ...        ...          ...           ...         ...
# 103414  210901.0     ざ   13765.25          NaN           NaN         NaN
# 104849  212336.0     ろ   13765.75          NaN           NaN         NaN
# 104761  212248.0     ゅ   13808.12          NaN           NaN         NaN
# 103790  211277.0     ぢ   13951.94          NaN           NaN         NaN
# 103870  211357.0     づ   13984.12          NaN           NaN         NaN
#
#         pron_count  spell_type simple_meaning meaning_origin  ... has_kanji  \
# 6582           1.0         0.0         的；所属               dp  ...     False
# 6712           1.0         0.0         主题助词               dp  ...     False
# 6246           1.0         0.0          在；向               dp  ...     False
# 2343           1.0         0.0         主语助词               dp  ...     False
# 9257           1.0         0.0         宾语助词               dp  ...     False
# ...            ...         ...            ...            ...  ...       ...
# 103414         1.0         0.0        杂音；表示轻蔑             dp  ...     False
# 104849         1.0         0.0         （古语助词）             dp  ...     False
# 104761         1.0         0.0    （平假名，无独立词义）             dp  ...     False
# 103790         1.0         0.0     ぢ（假名，同“じ”）             dp  ...     False
# 103870         1.0         0.0         （浊音符号）             dp  ...     False
#
#        hiragana_range katakana_range code  kanji_type  ck_long_word  \
# 6582             True          False  2.0         5.0          both
# 6712             True          False  2.0         5.0          both
# 6246             True          False  2.0         5.0          both
# 2343             True          False  2.0         5.0          both
# 9257             True          False  2.0         5.0          both
# ...               ...            ...  ...         ...           ...
# 103414           True          False  2.0         5.0     left_only
# 104849           True          False  2.0         5.0     left_only
# 104761           True          False  2.0         5.0     left_only
# 103790           True          False  2.0         5.0     left_only
# 103870           True          False  2.0         5.0     left_only
#
#        ck_base_word ck_5000_word ck_all_word spell_noise
# 6582           both         both        both           の
# 6712           both         both        both           は
# 6246           both         both        both           に
# 2343           both         both        both           が
# 9257           both         both        both           を
# ...             ...          ...         ...         ...
# 103414    left_only         both  right_only           ざ
# 104849    left_only         both  right_only           ろ
# 104761    left_only         both  right_only           ゅ
# 103790    left_only         both  right_only           ぢ
# 103870    left_only         both  right_only           づ
#
# [73 rows x 21 columns]

# %%
df_len_1_kata = df_increased_3000_final[
    (df_increased_3000_final["spell"].str.len() == 1)
    & (df_increased_3000_final["code"] == 1)
].copy()
df_len_1_kata
# Out:
#          word_id spell  frequency  spoken_freq  written_freq  mix_freq  \
# 104911  212398.0     ア      56.00          NaN           NaN       NaN
# 105134  212621.0     イ     169.00          NaN           NaN       NaN
# 105243  212730.0     ウ    1267.00          NaN           NaN       NaN
# 108782  216269.0     ー    2768.00          NaN           NaN       NaN
# 105334  212821.0     エ    2816.00          NaN           NaN       NaN
# ...          ...   ...        ...          ...           ...       ...
# 107941  215428.0     ボ   13840.12          NaN           NaN       NaN
# 107524  215011.0     ピ   13974.31          NaN           NaN       NaN
# 106664  214151.0     ダ   14016.44          NaN           NaN       NaN
# 106789  214276.0     ッ   14054.69          NaN           NaN       NaN
# 17134   117198.0     ネ   14478.19       4584.0           0.0    3058.0
#
#         pron_count  spell_type simple_meaning meaning_origin  ... has_kanji  \
# 104911         1.0         0.0          啊（感叹）             dp  ...     False
# 105134         1.0         0.0        无实义（假名）             dp  ...     False
# 105243         1.0         0.0       嗯、啊（语气词）             dp  ...     False
# 108782         1.0         0.0           长音符号             dp  ...     False
# 105334         1.0         0.0        表示惊讶或疑问             dp  ...     False
# ...            ...         ...            ...            ...  ...       ...
# 107941         1.0         0.0          轻微；微少             dp  ...     False
# 107524         1.0         0.0            字母P             dp  ...     False
# 106664         1.0         0.0           打；击打             dp  ...     False
# 106789         1.0         0.0             促音             dp  ...     False
# 17134          1.0         0.0        （口语）呢、啊             dp  ...     False
#
#        hiragana_range katakana_range code  kanji_type  ck_long_word  \
# 104911          False           True  1.0         6.0          both
# 105134          False           True  1.0         6.0     left_only
# 105243          False           True  1.0         6.0          both
# 108782          False           True  1.0         6.0     left_only
# 105334          False           True  1.0         6.0     left_only
# ...               ...            ...  ...         ...           ...
# 107941          False           True  1.0         6.0     left_only
# 107524          False           True  1.0         6.0     left_only
# 106664          False           True  1.0         6.0     left_only
# 106789          False           True  1.0         6.0     left_only
# 17134           False           True  1.0         6.0     left_only
#
#        ck_base_word ck_5000_word ck_all_word spell_noise
# 104911    left_only         both  right_only           ア
# 105134    left_only         both  right_only           イ
# 105243    left_only         both  right_only           ウ
# 108782    left_only         both  right_only           ー
# 105334    left_only         both  right_only           エ
# ...             ...          ...         ...         ...
# 107941    left_only         both  right_only           ボ
# 107524    left_only         both  right_only           ピ
# 106664    left_only         both  right_only           ダ
# 106789    left_only         both  right_only           ッ
# 17134          both    left_only        both           ネ
#
# [72 rows x 21 columns]

# %%
to_csv_sig(
    df_len_1_hira,
    "D:/Dropbox/06.wanjuan/99.tmp/df_len_1_hira.csv",
)

to_csv_sig(
    df_len_1_kata,
    "D:/Dropbox/06.wanjuan/99.tmp/df_len_1_kata.csv",
)
l("ok")
# Out:
# ----------------------------------------ok----------------------------------------
